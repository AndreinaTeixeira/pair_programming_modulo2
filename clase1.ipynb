# %% [markdown]
# Utilizando la API de Balldontlie, hazte un usuario para usar la API y extrae la siguiente información.
#
# El nombre, apellido y equipo de cada uno de los jugadores que tenemos en la NBA. Para eso tendrás que usar el siguiente endpoint https://api.balldontlie.io/v1/players. Extrae información de 200 jugadores. Devuelve los resultados en un DataFrame. Te deberá quedar algo parecido a esto:

# %%
API_key = "1e4a7f4e-73ca-40b9-a566-3a043c1d301c"

# %%
import requests

# %% [markdown]
# "api_endpoint_here" -H "Authorization: YOUR_API_KEY"

# %%
url = "https://api.balldontlie.io/v1/players"

# %%
headers = {"Authorization": API_key}

# %%
informacion = requests.get(url, headers=headers) 
print(informacion)
informacion.reason
# Out:
# <Response [200]>
# 'OK'

# %%
dictio = informacion.json()
dictio
# Out:
# {'data': [{'id': 1,
#    'first_name': 'Alex',
#    'last_name': 'Abrines',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '190',
#    'jersey_number': '8',
#    'college': 'FC Barcelona',
#    'country': 'Spain',
#    'draft_year': 2013,
#    'draft_round': 2,
#    'draft_number': 32,
#    'team': {'id': 21,
#     'conference': 'West',
#     'division': 'Northwest',
#     'city': 'Oklahoma City',
#     'name': 'Thunder',
#     'full_name': 'Oklahoma City Thunder',
#     'abbreviation': 'OKC'}},
#   {'id': 2,
#    'first_name': 'Jaylen',
#    'last_name': 'Adams',
#    'position': 'G',
#    'height': '6-0',
#    'weight': '225',
#    'jersey_number': '10',
#    'college': 'St. Bonaventure',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team': {'id': 1,
#     'conference': 'East',
#     'division': 'Southeast',
#     'city': 'Atlanta',
#     'name': 'Hawks',
#     'full_name': 'Atlanta Hawks',
# ...

# %% [markdown]
# usar len

# %%
for i in dictio["data"]:
    print(i["first_name"])
# Out:
# Alex
# Jaylen
# Steven
# Bam
# DeVaughn
# LaMarcus
# Rawle
# Grayson
# Jarrett
# Al-Farouq
# Justin
# Kyle
# Ryan
# Ike
# Giannis
# Kostas
# Carmelo
# OG
# Ryan
# Trevor
# D.J.
# Deandre
# Dwayne
# Marvin
# Ron

# %%
jugadores = [f"{i['first_name']} {i['last_name']} from team: {i['team']["full_name"]}" for i in dict["data"]]
jugadores
# Out:
# ['Alex Abrines from team: Oklahoma City Thunder',
#  'Jaylen Adams from team: Atlanta Hawks',
#  'Steven Adams from team: Houston Rockets',
#  'Bam Adebayo from team: Miami Heat',
#  'DeVaughn Akoon-Purcell from team: Denver Nuggets',
#  'LaMarcus Aldridge from team: Brooklyn Nets',
#  'Rawle Alkins from team: Chicago Bulls',
#  'Grayson Allen from team: Phoenix Suns',
#  'Jarrett Allen from team: Cleveland Cavaliers',
#  'Al-Farouq Aminu from team: Portland Trail Blazers',
#  'Justin Anderson from team: Indiana Pacers',
#  'Kyle Anderson from team: Miami Heat',
#  'Ryan Anderson from team: New Orleans Pelicans',
#  'Ike Anigbogu from team: Indiana Pacers',
#  'Giannis Antetokounmpo from team: Milwaukee Bucks',
#  'Kostas Antetokounmpo from team: Chicago Bulls',
#  'Carmelo Anthony from team: Los Angeles Lakers',
#  'OG Anunoby from team: New York Knicks',
#  'Ryan Arcidiacono from team: New York Knicks',
#  'Trevor Ariza from team: Los Angeles Lakers',
# ...

# %%
for i in informacion.json().values():
    print(i)
# Out:
# [{'id': 1, 'first_name': 'Alex', 'last_name': 'Abrines', 'position': 'G', 'height': '6-6', 'weight': '190', 'jersey_number': '8', 'college': 'FC Barcelona', 'country': 'Spain', 'draft_year': 2013, 'draft_round': 2, 'draft_number': 32, 'team': {'id': 21, 'conference': 'West', 'division': 'Northwest', 'city': 'Oklahoma City', 'name': 'Thunder', 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC'}}, {'id': 2, 'first_name': 'Jaylen', 'last_name': 'Adams', 'position': 'G', 'height': '6-0', 'weight': '225', 'jersey_number': '10', 'college': 'St. Bonaventure', 'country': 'USA', 'draft_year': None, 'draft_round': None, 'draft_number': None, 'team': {'id': 1, 'conference': 'East', 'division': 'Southeast', 'city': 'Atlanta', 'name': 'Hawks', 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL'}}, {'id': 3, 'first_name': 'Steven', 'last_name': 'Adams', 'position': 'C', 'height': '6-11', 'weight': '265', 'jersey_number': '12', 'college': 'Pittsburgh', 'country': 'New Zealand', 'draft_year
# ...

# %%
values = informacion.json().values()
list(values)
# Out:
# [[{'id': 1,
#    'first_name': 'Alex',
#    'last_name': 'Abrines',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '190',
#    'jersey_number': '8',
#    'college': 'FC Barcelona',
#    'country': 'Spain',
#    'draft_year': 2013,
#    'draft_round': 2,
#    'draft_number': 32,
#    'team': {'id': 21,
#     'conference': 'West',
#     'division': 'Northwest',
#     'city': 'Oklahoma City',
#     'name': 'Thunder',
#     'full_name': 'Oklahoma City Thunder',
#     'abbreviation': 'OKC'}},
#   {'id': 2,
#    'first_name': 'Jaylen',
#    'last_name': 'Adams',
#    'position': 'G',
#    'height': '6-0',
#    'weight': '225',
#    'jersey_number': '10',
#    'college': 'St. Bonaventure',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team': {'id': 1,
#     'conference': 'East',
#     'division': 'Southeast',
#     'city': 'Atlanta',
#     'name': 'Hawks',
#     'full_name': 'Atlanta Hawks',
# ...

# %%
players = list(values)
players[0][0:99]
# Out:
# [{'id': 1,
#   'first_name': 'Alex',
#   'last_name': 'Abrines',
#   'position': 'G',
#   'height': '6-6',
#   'weight': '190',
#   'jersey_number': '8',
#   'college': 'FC Barcelona',
#   'country': 'Spain',
#   'draft_year': 2013,
#   'draft_round': 2,
#   'draft_number': 32,
#   'team': {'id': 21,
#    'conference': 'West',
#    'division': 'Northwest',
#    'city': 'Oklahoma City',
#    'name': 'Thunder',
#    'full_name': 'Oklahoma City Thunder',
#    'abbreviation': 'OKC'}},
#  {'id': 2,
#   'first_name': 'Jaylen',
#   'last_name': 'Adams',
#   'position': 'G',
#   'height': '6-0',
#   'weight': '225',
#   'jersey_number': '10',
#   'college': 'St. Bonaventure',
#   'country': 'USA',
#   'draft_year': None,
#   'draft_round': None,
#   'draft_number': None,
#   'team': {'id': 1,
#    'conference': 'East',
#    'division': 'Southeast',
#    'city': 'Atlanta',
#    'name': 'Hawks',
#    'full_name': 'Atlanta Hawks',
#    'abbreviation': 'ATL'}},
#  {'id': 3,
# ...

# %%
len(values)
# Out:
# 2

# %%
players = list(values)[0]
for player in players:
    print(players[0:199])
# Out:
# [{'id': 1, 'first_name': 'Alex', 'last_name': 'Abrines', 'position': 'G', 'height': '6-6', 'weight': '190', 'jersey_number': '8', 'college': 'FC Barcelona', 'country': 'Spain', 'draft_year': 2013, 'draft_round': 2, 'draft_number': 32, 'team': {'id': 21, 'conference': 'West', 'division': 'Northwest', 'city': 'Oklahoma City', 'name': 'Thunder', 'full_name': 'Oklahoma City Thunder', 'abbreviation': 'OKC'}}, {'id': 2, 'first_name': 'Jaylen', 'last_name': 'Adams', 'position': 'G', 'height': '6-0', 'weight': '225', 'jersey_number': '10', 'college': 'St. Bonaventure', 'country': 'USA', 'draft_year': None, 'draft_round': None, 'draft_number': None, 'team': {'id': 1, 'conference': 'East', 'division': 'Southeast', 'city': 'Atlanta', 'name': 'Hawks', 'full_name': 'Atlanta Hawks', 'abbreviation': 'ATL'}}, {'id': 3, 'first_name': 'Steven', 'last_name': 'Adams', 'position': 'C', 'height': '6-11', 'weight': '265', 'jersey_number': '12', 'college': 'Pittsburgh', 'country': 'New Zealand', 'draft_year
# ...

# %%
type(values)
# Out:
# dict_values

# %%
for value in informacion.json():
    print(value[0])
# Out:
# d
# m

# %%
import pandas as pd

# %% [markdown]
# Y para este caso en particular podríamos utilizar "params" en nuestras llamadas API ya que por defecto solo podrás traer 25 jugadores por petición y un máximo de 100 en cada petición.

# %% [markdown]
# Extrae información de todos los equipos, con la información que estos mismos traen, puedes encontrar la conferencia a la que pertenece, la ciudad, el nombre y su abreviación. En este caso ustedes deben buscar por dentro de la pagina cual es endpoint que correspondería a esta petición.
